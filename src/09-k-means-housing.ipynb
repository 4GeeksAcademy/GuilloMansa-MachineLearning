# %% [markdown]
# #### **K-Means**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from yellowbrick.cluster import KElbowVisualizer
from sklearn.metrics import silhouette_score, davies_bouldin_score

# %% [markdown]
# - Sistema de agrupación de casas
#
# Queremos ser capaces de clasificar casas según su la región en la que se encuentren y del ingreso medio. Para ello, utilizaremos el famoso conjunto de datos California Housing. Se construyó utilizando los datos del censo de California de 1990. Contiene una fila por grupo de bloques censales. Un grupo de bloques es la unidad geográfica más pequeña para la que se publican datos del censo de USA.

# %%
df = pd.read_csv('/workspaces/GuilloMansa-MachineLearning/data/raw/housing.csv', sep=',')
df.head(5)
# Out:
#    MedInc  HouseAge  AveRooms  ...  Latitude  Longitude  MedHouseVal
# 0  8.3252      41.0  6.984127  ...     37.88    -122.23        4.526
# 1  8.3014      21.0  6.238137  ...     37.86    -122.22        3.585
# 2  7.2574      52.0  8.288136  ...     37.85    -122.24        3.521
# 3  5.6431      52.0  5.817352  ...     37.85    -122.25        3.413
# 4  3.8462      52.0  6.281853  ...     37.85    -122.25        3.422
#
# [5 rows x 9 columns]

# %%
X = df[["MedInc", "Latitude", "Longitude"]]
X.head()
# Out:
#    MedInc  Latitude  Longitude
# 0  8.3252     37.88    -122.23
# 1  8.3014     37.86    -122.22
# 2  7.2574     37.85    -122.24
# 3  5.6431     37.85    -122.25
# 4  3.8462     37.85    -122.25

# %% [markdown]
# Construir Kmeans

# %%
df
# Out:
#        MedInc  HouseAge  AveRooms  ...  Latitude  Longitude  MedHouseVal
# 0      8.3252      41.0  6.984127  ...     37.88    -122.23        4.526
# 1      8.3014      21.0  6.238137  ...     37.86    -122.22        3.585
# 2      7.2574      52.0  8.288136  ...     37.85    -122.24        3.521
# 3      5.6431      52.0  5.817352  ...     37.85    -122.25        3.413
# 4      3.8462      52.0  6.281853  ...     37.85    -122.25        3.422
# ...       ...       ...       ...  ...       ...        ...          ...
# 20635  1.5603      25.0  5.045455  ...     39.48    -121.09        0.781
# 20636  2.5568      18.0  6.114035  ...     39.49    -121.21        0.771
# 20637  1.7000      17.0  5.205543  ...     39.43    -121.22        0.923
# 20638  1.8672      18.0  5.329513  ...     39.43    -121.32        0.847
# 20639  2.3886      16.0  5.254717  ...     39.37    -121.24        0.894
#
# [20640 rows x 9 columns]

# %%
fig, axes = plt.subplots(1, 3, figsize=(10, 4))
sns.histplot(ax=axes[0], data=df, x="Latitude", bins=20)
axes[0]
sns.histplot(ax=axes[1], data=df, x="Longitude", bins=20)
axes[1]
sns.histplot(ax=axes[2], data=df, x="MedInc", bins=20)
axes[2]
plt.tight_layout()
plt.show()
# Out:
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# ...

# %% [markdown]
# Como vemos que no existe una distribucion normal para poder seguir aplicando, debemos normalizar los datos.

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler
min_max_scaler = MinMaxScaler()

num_variables = ['Latitude','Longitude', 'MedInc']
min_max_features = min_max_scaler.fit_transform(df[num_variables])

df_scaled = pd.DataFrame( min_max_features, index = df.index,columns=num_variables)

# %%
fig, axis = plt.subplots(1, 3, figsize = (15, 5))

sns.scatterplot(ax = axis[0], data = df, x = "Latitude", y = "Longitude", hue = "cluster", palette = "deep")
sns.scatterplot(ax = axis[1], data = df, x = "Latitude", y = "MedInc", hue = "cluster", palette = "deep")
sns.scatterplot(ax = axis[2], data = df, x = "Longitude", y = "MedInc", hue = "cluster", palette = "deep")
plt.tight_layout()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[72], line 3
#       1 fig, axis = plt.subplots(1, 3, figsize = (15, 5))
# ----> 3 sns.scatterplot(ax = axis[0], data = df, x = "Latitude", y = "Longitude", hue = "cluster", palette = "deep")
#       4 sns.scatterplot(ax = axis[1], data = df, x = "Latitude", y = "MedInc", hue = "cluster", palette = "deep")
#       5 sns.scatterplot(ax = axis[2], data = df, x = "Longitude", y = "MedInc", hue = "cluster", palette = "deep")
#
# File ~/.local/lib/python3.11/site-packages/seaborn/relational.py:615, in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     606 def scatterplot(
#     607     data=None, *,
#     608     x=None, y=None, hue=None, size=None, style=None,
#    (...)    612     **kwargs
#     613 ):
# ...

# %%
elbow_vis = KElbowVisualizer(KMeans(random_state=18), k=(2, 20))
elbow_vis.fit(X)
elbow_vis.show()
# Out:
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# ...

# %% [markdown]
# El metodo Elbow nos dice que la sugerencia es con cluster = 8.

# %%
modelKM = KMeans(n_clusters = 6, n_init = "auto", random_state = 42)
modelKM.fit(df)
df["cluster"] = modelKM.predict(df)

# %%
prediccion = modelKM.predict(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 prediccion = modelKM.predict(df)
#
# File ~/.local/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1085, in _BaseKMeans.predict(self, X)
#    1067 """Predict the closest cluster each sample in X belongs to.
#    1068
#    1069 In the vector quantization literature, `cluster_centers_` is called
#    (...)   1081     Index of the cluster each sample belongs to.
#    1082 """
#    1083 check_is_fitted(self)
# -> 1085 X = self._check_test_data(X)
#    1087 # sample weights are not used by predict but cython helpers expect an array
#    1088 sample_weight = np.ones(X.shape[0], dtype=X.dtype)
#
# File ~/.local/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:944, in _BaseKMeans._check_test_data(self, X)
#     943 def _check_test_data(self, X):
# --> 944     X = validate_data(
# ...

# %%
df['cluster']= prediccion
